# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import calendar

# %%
test_date = dt.datetime(2017,8,25)

# %%
df = pd.read_csv("transactions.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index(df['Date']).drop('Date',axis=1)

# %%
x = pd.to_datetime('2017-08-25')

# %%
def process_raw(tab):
    df = tab
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.set_index(df['Date']).drop('Date',axis=1)
    return df

# %%
process_raw(pd.read_csv("transactions.csv"))
# Out:
#                                  Description  \
# Date
# 2017-09-09                     Gig Car Share
# 2017-09-09                     Gig Car Share
# 2017-09-10                              Lyft
# 2017-09-10                              Lyft
# 2017-09-09                       Cafe Durant
# 2017-09-08          Diyar Mediterranean Cusi
# 2017-08-31                      Raleighs Pub
# 2017-08-31                Internet Thank You
# 2017-08-29                Internet Thank You
# 2017-08-29           Ucb Recreational Sports
# 2017-08-27            Berkeley Bowl Markesbe
# 2017-08-26          Chengdu Style Restaurant
# 2017-08-25                          V A Cafe
# 2017-08-25                              Lyft
# 2017-08-25                              Lyft
# 2017-08-25                           L Epi D
# 2017-08-25                              Lyft
# 2017-08-24  Transfer from BofA Core Checking
# 2017-08-23                     Laval's Pizza
# 2017-08-21                       Chick-Fil-A
# 2017-08-21                             Tea 1
# 2017-08-21                            Amazon
# 2017-08-20                            Amazon
# 2017-08-20                              Lyft
# 2017-08-19                           Comcast
# 2017-08-18                              Lyft
# 2017-08-17                     Laval's Pizza
# 2017-08-13          Diyar Mediterranean Cusi
# 2017-08-12                              Lyft
# 2017-08-12                           Safeway
# ...                                      ...
# 2016-11-10                    Ucafe Berkeley
# 2016-11-10                    La Val's Pizza
# 2016-11-09                  Dumpling Express
# 2016-11-06              Ation 723 Tea Street
# 2016-11-04                            Amazon
# 2016-11-03                        Artichokes
# 2016-11-02              Cafe Strada Berkeley
# 2016-11-02                            Amazon
# 2016-10-30                  Dumpling Express
# 2016-10-30                            Amazon
# 2016-10-30                  Dumpling Express
# 2016-10-29                            Amazon
# 2016-10-26                          Sharetea
# 2016-10-24                            Amazon
# 2016-10-23                Internet Thank You
# 2016-10-23                Ucb Housing Dining
# 2016-10-16                            Amazon
# 2016-10-15                  Dumpling Express
# 2016-10-15                            Amazon
# 2016-10-15                            Amazon
# 2016-10-14              Cafe Strada Berkeley
# 2016-10-07                  Dumpling Express
# 2016-10-01                   Sweetheart Cafe
# 2016-09-30                            Amazon
# 2016-09-26                            Amazon
# 2016-09-26                       Simply Bowl
# 2016-09-25                            Amazon
# 2016-09-25                Ucb Housing Dining
# 2016-09-24                            Amazon
# 2016-09-24                Internet Thank You
#
#                                          Original Description  Amount  \
# Date
# 2017-09-09                                      GIG CAR SHARE    0.50
# 2017-09-09                                      GIG CAR SHARE    0.50
# 2017-09-10                 LYFT *RIDE SUN 2PM 855-280-0278 CA   15.38
# 2017-09-10                 LYFT *RIDE SUN 4PM 855-280-0278 CA   10.88
# 2017-09-09                            CAFE DURANT BERKELEY CA    9.66
# 2017-09-08               DIYAR MEDITERRANEAN CUSI BERKELEY CA    8.73
# 2017-08-31                           RALEIGHS PUB BERKELEY CA   10.87
# 2017-08-31                       INTERNET PAYMENT - THANK YOU  225.61
# 2017-08-29                       INTERNET PAYMENT - THANK YOU  155.53
# 2017-08-29            UCB RECREATIONAL SPORTS 510-642-7796 CA   25.00
# 2017-08-27                 BERKELEY BOWL MARKESBE BERKELEY CA  200.61
# 2017-08-26               CHENGDU STYLE RESTAURANT BERKELEY CA   63.00
# 2017-08-25     SQ *V&A CAFE BERKELEY CA0002305843011213890465    3.00
# 2017-08-25                LYFT *RIDE FRI 12PM 855-280-0278 CA   11.69
# 2017-08-25                LYFT *RIDE FRI 12PM 855-280-0278 CA   35.11
# 2017-08-25  SQ *L'EPI D'OR BAKERY CUPERTINO CA000115292150...    4.99
# 2017-08-25                LYFT *RIDE FRI 10AM 855-280-0278 CA   30.85
# 2017-08-24                       INTERNET PAYMENT - THANK YOU  383.82
# 2017-08-23                          LAVAL'S PIZZA BERKELEY CA    6.89
# 2017-08-21                 CHICK-FIL-A #02765 WALNUT CREEK CA    8.39
# 2017-08-21  SQ *TEA 1 BERKELEY BERKELEY CA0002305843011209...    4.25
# 2017-08-21              AMAZON.COM AMZN.COM/BILLWA6M1Q94EWTEI   15.32
# 2017-08-20              AMAZON.COM AMZN.COM/BILLWA49VLZN1FMGG   15.42
# 2017-08-20                 LYFT *RIDE SUN 7PM 855-280-0278 CA    6.50
# 2017-08-19  COMCAST CALIFORN CS 1X 800-266-2278 CA73603189...   39.99
# 2017-08-18                 LYFT *RIDE FRI 8PM 855-280-0278 CA    7.09
# 2017-08-17                          LAVAL'S PIZZA BERKELEY CA    8.75
# 2017-08-13               DIYAR MEDITERRANEAN CUSI BERKELEY CA   18.55
# 2017-08-12                 LYFT *RIDE SAT 3PM 855-280-0278 CA    6.50
# 2017-08-12                     SAFEWAY STORE 0691 BERKELEY CA   93.20
# ...                                                       ...     ...
# 2016-11-10  SQ *UCAFE, BERKELEY BERKELEY CA000115292150743...    2.75
# 2016-11-10                          LAVAL'S PIZZA BERKELEY CA    9.30
# 2016-11-09                       DUMPLING EXPRESS BERKELEY CA    8.54
# 2016-11-06                        723 TEA STATION BERKELEY CA    8.27
# 2016-11-04    AMAZON PICKUP POINTS 877-345-0975 WAVHOYB211YRP   25.61
# 2016-11-03  SQ *ARTICHOKE BASILLE' BERKELEY CA000115292150...    5.20
# 2016-11-02                       CAFE STRADA, INC BERKELEY CA    2.95
# 2016-11-02              AMAZON.COM AMZN.COM/BILLWAS92AN8Q6MPU   12.41
# 2016-10-30                       DUMPLING EXPRESS BERKELEY CA    8.54
# 2016-10-30    AMAZON MKTPLACE PMTS AMZN.COM/BILLWAQXI26QETC0G   10.94
# 2016-10-30                       DUMPLING EXPRESS BERKELEY CA    8.54
# 2016-10-29    AMAZON MKTPLACE PMTS AMZN.COM/BILLWAQXIRBS5R0F1   25.97
# 2016-10-26     SQ *SHARETEA BERKELEY CA0001152921507419964410    4.10
# 2016-10-24    AMAZON PICKUP POINTS 877-345-0975 WAEIYIHN10TWM   17.37
# 2016-10-23                       INTERNET PAYMENT - THANK YOU  136.10
# 2016-10-23            UCB HOUSING&DINING SVCS 510-643-6955 CA   20.00
# 2016-10-16    AMAZON PICKUP POINTS 877-345-0975 WAG4Q9R3IKRN9   14.22
# 2016-10-15                       DUMPLING EXPRESS BERKELEY CA    8.04
# 2016-10-15    AMAZON MKTPLACE PMTS AMZN.COM/BILLWAKYG48B5SZM0   16.95
# 2016-10-15    AMAZON PICKUP POINTS 877-345-0975 WAI8CZU4V6UT0   11.60
# 2016-10-14                       CAFE STRADA, INC BERKELEY CA    1.95
# 2016-10-07                       DUMPLING EXPRESS BERKELEY CA    8.54
# 2016-10-01  SQ *SWEETHEART CAFE BERKELEY CA000115292150739...    3.11
# 2016-09-30    AMAZON PICKUP POINTS 877-345-0975 WAQNFQ0I2N5VZ   12.46
# 2016-09-26    AMAZON MKTPLACE PMTS AMZN.COM/BILLWAPSZW18FL65W   12.95
# 2016-09-26                            SIMPLY BOWL BERKELEY CA   11.50
# 2016-09-25    AMAZON MKTPLACE PMTS AMZN.COM/BILLWAILEP1GHK5UI    4.95
# 2016-09-25            UCB HOUSING&DINING SVCS 510-643-6955 CA   20.00
# 2016-09-24    AMAZON PICKUP POINTS 877-345-0975 WATZP495DA69Q    9.83
# 2016-09-24                       INTERNET PAYMENT - THANK YOU  234.66
#
#            Transaction Type                    Category Account Name  Labels  \
# Date
# 2017-09-09            debit       Transportation & Taxi     Discover     NaN
# 2017-09-09            debit       Transportation & Taxi     Discover     NaN
# 2017-09-10            debit       Transportation & Taxi     Discover     NaN
# 2017-09-10            debit       Transportation & Taxi     Discover     NaN
# 2017-09-09            debit                 Restaurants     Discover     NaN
# 2017-09-08            debit                 Restaurants     Discover     NaN
# 2017-08-31            debit                 Restaurants     Discover     NaN
# 2017-08-31           credit         Credit Card Payment     Discover     NaN
# 2017-08-29           credit         Credit Card Payment     Discover     NaN
# 2017-08-29            debit               Entertainment     Discover     NaN
# 2017-08-27            debit                        Food     Discover     NaN
# 2017-08-26            debit                 Restaurants     Discover     NaN
# 2017-08-25            debit                 Restaurants     Discover     NaN
# 2017-08-25            debit       Transportation & Taxi     Discover     NaN
# 2017-08-25            debit       Transportation & Taxi     Discover     NaN
# 2017-08-25            debit                 Restaurants     Discover     NaN
# 2017-08-25            debit       Transportation & Taxi     Discover     NaN
# 2017-08-24           credit         Credit Card Payment     Discover     NaN
# 2017-08-23            debit                 Restaurants     Discover     NaN
# 2017-08-21            debit                 Restaurants     Discover     NaN
# 2017-08-21            debit                 Restaurants     Discover     NaN
# 2017-08-21            debit                    Shopping     Discover     NaN
# 2017-08-20            debit                    Shopping     Discover     NaN
# 2017-08-20            debit       Transportation & Taxi     Discover     NaN
# 2017-08-19            debit               Entertainment     Discover     NaN
# 2017-08-18            debit       Transportation & Taxi     Discover     NaN
# 2017-08-17            debit                 Restaurants     Discover     NaN
# 2017-08-13            debit                 Restaurants     Discover     NaN
# 2017-08-12            debit       Transportation & Taxi     Discover     NaN
# 2017-08-12            debit                        Food     Discover     NaN
# ...                     ...                         ...          ...     ...
# 2016-11-10            debit                 Restaurants     Discover     NaN
# 2016-11-10            debit                 Restaurants     Discover     NaN
# 2016-11-09            debit                 Restaurants     Discover     NaN
# 2016-11-06            debit                Restaurantss     Discover     NaN
# 2016-11-04            debit                    Shopping     Discover     NaN
# 2016-11-03            debit                 Restaurants     Discover     NaN
# 2016-11-02            debit                Restaurantss     Discover     NaN
# 2016-11-02            debit                    Shopping     Discover     NaN
# 2016-10-30            debit                 Restaurants     Discover     NaN
# 2016-10-30            debit                    Shopping     Discover     NaN
# 2016-10-30            debit                 Restaurants     Discover     NaN
# 2016-10-29            debit                    Shopping     Discover     NaN
# 2016-10-26            debit                 Restaurants     Discover     NaN
# 2016-10-24            debit                    Shopping     Discover     NaN
# 2016-10-23           credit         Credit Card Payment     Discover     NaN
# 2016-10-23            debit  Transfer for Cash Spending     Discover     NaN
# 2016-10-16            debit                    Shopping     Discover     NaN
# 2016-10-15            debit                 Restaurants     Discover     NaN
# 2016-10-15            debit                    Shopping     Discover     NaN
# 2016-10-15            debit                    Shopping     Discover     NaN
# 2016-10-14            debit                Restaurantss     Discover     NaN
# 2016-10-07            debit                 Restaurants     Discover     NaN
# 2016-10-01            debit                Restaurantss     Discover     NaN
# 2016-09-30            debit                    Shopping     Discover     NaN
# 2016-09-26            debit                    Shopping     Discover     NaN
# 2016-09-26            debit                 Restaurants     Discover     NaN
# 2016-09-25            debit                    Shopping     Discover     NaN
# 2016-09-25            debit  Transfer for Cash Spending     Discover     NaN
# 2016-09-24            debit                    Shopping     Discover     NaN
# 2016-09-24           credit         Credit Card Payment     Discover     NaN
#
#             Notes
# Date
# 2017-09-09    NaN
# 2017-09-09    NaN
# 2017-09-10    NaN
# 2017-09-10    NaN
# 2017-09-09    NaN
# 2017-09-08    NaN
# 2017-08-31    NaN
# 2017-08-31    NaN
# 2017-08-29    NaN
# 2017-08-29    NaN
# 2017-08-27    NaN
# 2017-08-26    NaN
# 2017-08-25    NaN
# 2017-08-25    NaN
# 2017-08-25    NaN
# 2017-08-25    NaN
# 2017-08-25    NaN
# 2017-08-24    NaN
# 2017-08-23    NaN
# 2017-08-21    NaN
# 2017-08-21    NaN
# 2017-08-21    NaN
# 2017-08-20    NaN
# 2017-08-20    NaN
# 2017-08-19    NaN
# 2017-08-18    NaN
# 2017-08-17    NaN
# 2017-08-13    NaN
# 2017-08-12    NaN
# 2017-08-12    NaN
# ...           ...
# 2016-11-10    NaN
# 2016-11-10    NaN
# 2016-11-09    NaN
# 2016-11-06    NaN
# 2016-11-04    NaN
# 2016-11-03    NaN
# 2016-11-02    NaN
# 2016-11-02    NaN
# 2016-10-30    NaN
# 2016-10-30    NaN
# 2016-10-30    NaN
# 2016-10-29    NaN
# 2016-10-26    NaN
# 2016-10-24    NaN
# 2016-10-23    NaN
# 2016-10-23    NaN
# 2016-10-16    NaN
# 2016-10-15    NaN
# 2016-10-15    NaN
# 2016-10-15    NaN
# 2016-10-14    NaN
# 2016-10-07    NaN
# 2016-10-01    NaN
# 2016-09-30    NaN
# 2016-09-26    NaN
# 2016-09-26    NaN
# 2016-09-25    NaN
# 2016-09-25    NaN
# 2016-09-24    NaN
# 2016-09-24    NaN
#
# [288 rows x 8 columns]

# %%
to = dt.datetime.today()

# %%
categories = set(df['Category'])
print(categories)
# Out:
# {'Entertainment', 'Restaurants', 'Transportation & Taxi', 'Restaurantss', 'Apparel and Clothing', 'Transfer for Cash Spending', 'Health Care', 'Clothing', 'Mortgage & Rent', 'Advertising', 'Sporting Goods', 'Transportation', 'Pharmacy', 'Tuition', 'Food', 'Credit Card Payment', 'Gift', 'Shopping'}

# %%
getRangeExpenditure(df, to,to)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c0f4d9560f9c> in <module>()
# ----> 1 getRangeExpenditure(df, to,to)
#
# NameError: name 'getRangeExpenditure' is not defined

# %%
def getTodayExpenditure(tab, today=dt.datetime.today()):
    '''gets amount of money spent toady'''
    if (today not in tab.index):
        return 0
    today_transactions = tab.loc[today.date()]
    return sum(today_transactions['Amount'])

# %%
test = getTodayExpenditure(df,test_date)
print("$",round(test,2))

# %%
to

# %%
to - dt.timedelta(days=7)

# %%
a = [i for i in pd.date_range(to, to).values if i in df.index.values]

# %%
getFrequencies(df, test_date,test_date)

# %%
date_range = [i for i in pd.date_range(test_date, test_date).values if i in df.index.values]

# %%
transaction_range

# %%
def getRangeExpenditure(tab, date_start, date_end, category=None):
    '''returns the amount of money spent in date range'''
    date_range = [i for i in pd.date_range(date_start, date_end).values if i in tab.index.values]
    if (len(date_range)==0):
        return 0
    today_transactions = tab.loc[date_range]
    today_transactions.head()
    if (category==None):
        return sum(today_transactions['Amount'])
    else:
        return sum(today_transactions[today_transactions['Category']==category]['Amount'])

# %%
getRangeExpenditure(df, (dt.datetime.today()-dt.timedelta(days=60)).date(),dt.datetime.today().date(), 'Restaurants')

# %%
def getFrequencies(tab, start_day, end_day, freq='daily'):
    date_range = [i for i in pd.date_range(start_day, end_day).values if i in tab.index.values]
    out = create_categories_map(tab)
    if (len(date_range)==0):
        return out
    transaction_range = tab.loc[date_range]
    out_val = transaction_range.groupby('Category')['Amount'].sum().to_dict()
    diff_days = (end_day - start_day).days
    if (diff_days==0):
        diff_days = 1
        
    if (freq == 'weekly'):
        r = diff_days/7
    elif (freq=='monthly'):
        r = diff_days/30
    elif (freq=='yearly'):
        r = diff_days/365
    else:
        r = diff_days
    for k in out_val:
        out_val[k] = out_val[k]/r
        out[k] = out_val[k]
    return out

# %%
def getFrequenciesCounts(tab, start_day, end_day, freq='daily'):
    date_range = [i for i in pd.date_range(start_day, end_day).values if i in tab.index.values]
    out = create_categories_map(tab)
    if (len(date_range)==0):
        return out
    transaction_range = tab.loc[date_range]
    out_val = transaction_range['Category'].value_counts().to_dict()
    diff_days = (end_day - start_day).days
    if (diff_days==0):
        diff_days = 1
        
    if (freq == 'weekly'):
        r = diff_days/7
    elif (freq=='monthly'):
        r = diff_days/30
    elif (freq=='yearly'):
        r = diff_days/365
    else:
        r = diff_days
    for k in out_val:
        out_val[k] = out_val[k]/r
        out[k] = out_val[k]
    return out

# %%
getFrequenciesCounts(df, x, to)

# %%
def getOccurrencies(tab, start_day, end_day, freq='daily'):
    transaction_range = tab.loc[[i for i in pd.date_range(start_day, end_day).values if i in tab.index.values]]
    out = transaction_range['Category'].value_counts().to_dict()
    return out

# %%
(test_date+dt.timedelta(days=2)).weekday()

# %%
def getFrequencyDate(time, freq='daily'):
    """returns the start and end dates based on the given frequency
    possible freq = 'daily', 'weekly', 'monthly', 'yearly' """
    if (freq=='weekly'):
        start = time - dt.timedelta(days=time.weekday())
        end = start + dt.timedelta(days=6)
    elif (freq=='monthly'):
        start = time.replace(day=1)
        start_day, end_day = calendar.monthrange(time.year,time.month)
        end = time.replace(day=end_day)
    elif (freq=='yearly'):
        start = time.replace(month=1).replace(day=1)
        end = time.replace(month=12).replace(day=31)
    else:
        start = time
        end = time
    return start, end

# %%
x = pd.to_datetime(to)

# %%
overall_f = full_category_frequencies(df,'weekly')

# %%
overall_f

# %%
def full_category_frequencies(tab, freq='Daily'):
    return getFrequencies(tab, min(tab.index), max(tab.index), freq)

# %%
def full_category_frequencies_counts(tab, freq='Daily'):
    return getFrequenciesCounts(tab, min(tab.index), max(tab.index), freq)

# %%
df[df['Description'] == 'Tea Cory Hall']

# %%
df.index

# %%
def create_categories_map(tab, label='Category'):
    cat_set = set(tab[label])
    out = dict()
    for c in cat_set:
        out[c] = 0
    return out

# %%
getFrequencies(df, pd.to_datetime("2017-08-01"),pd.to_datetime("2017-09-01"),'weekly')

# %%
full_category_frequencies(df, 'weekly')

# %%
df[df['Category']=='Credit Card Payment']

# %%
data = pd.read_excel('age.xls')

# %%
data.head()
